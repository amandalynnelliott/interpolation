# %%
import pandas as pd
from pandas import HDFStore, DataFrame
from pandas import read_hdf
import numpy as np
from matplotlib import pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C
from scipy.interpolate import interp1d
from scipy import interpolate
# %matplotlib inline

# %%
# open hdf5 file for reading
hdf = pd.HDFStore('NNLO_templates.h5', mode='r')

# %%
hdf.keys()
# Out:
# ['/Eneg', '/Ep_Em', '/Epos', '/Mll', '/ptll', '/ptneg', '/ptp_ptm', '/ptpos']

# %%
Eneg = hdf.get('/Eneg')
print(type(Eneg))
print(hdf.get('Eneg').shape)
Eneg.head(69)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (69, 7)
#      Eneg  bin   binContent    binError  binWidth2     mt  scaling
# 1    25.0    1  5601.069641   63.808391        5.0  171.5   111612
# 2    35.0    2  9236.127385   92.972350        5.0  171.5   111612
# 3    45.0    3  9972.900520   90.501126        5.0  171.5   111612
# 4    55.0    4  9515.469899  103.878103        5.0  171.5   111612
# 5    65.0    5  8479.409186   98.263629        5.0  171.5   111612
# ..    ...  ...          ...         ...        ...    ...      ...
# 19  205.0   19  1022.512886   30.762017        5.0  173.5   107642
# 20  215.0   20   840.699090   34.022213        5.0  173.5   107642
# 21  225.0   21   756.581173   30.799046        5.0  173.5   107642
# 22  235.0   22   648.877817   24.170785        5.0  173.5   107642
# 23  245.0   23   591.061146   23.474277        5.0  173.5   107642
#
# [69 rows x 7 columns]

# %%
Ep_Em = hdf.get('/Ep_Em')
type(Ep_Em)
print(hdf.get('Ep_Em').shape)
Ep_Em.head(100)
# Out:
# (135, 7)
#     Ep_Em  bin   binContent   binError  binWidth2     mt  scaling
# 1    55.0    1   474.137821  16.683427        5.0  171.5   111612
# 2    65.0    2  1385.116081  28.176784        5.0  171.5   111612
# 3    75.0    3  2564.743309  37.049603        5.0  171.5   111612
# 4    85.0    4  3525.789596  55.753542        5.0  171.5   111612
# 5    95.0    5  4405.537703  62.384635        5.0  171.5   111612
# ..    ...  ...          ...        ...        ...    ...      ...
# 6   105.0    6  4404.172430  58.601489        5.0  173.5   107642
# 7   115.0    7  4697.959741  58.069953        5.0  173.5   107642
# 8   125.0    8  4876.408648  61.500396        5.0  173.5   107642
# 9   135.0    9  4671.598215  62.844844        5.0  173.5   107642
# 10  145.0   10  4714.687307  60.557344        5.0  173.5   107642
#
# [100 rows x 7 columns]

# %%
Epos = hdf.get('/Epos')
type(Epos)
print(hdf.get('Epos').shape)
Epos.head(100)
# Out:
# (69, 7)
#      Epos  bin   binContent   binError  binWidth2     mt  scaling
# 1    25.0    1  5471.577398  58.043854        5.0  171.5   111612
# 2    35.0    2  9274.588880  79.039946        5.0  171.5   111612
# 3    45.0    3  9867.795499  87.639897        5.0  171.5   111612
# 4    55.0    4  9610.853514  92.046193        5.0  171.5   111612
# 5    65.0    5  8485.257655  92.545847        5.0  171.5   111612
# ..    ...  ...          ...        ...        ...    ...      ...
# 19  205.0   19   976.176235  31.297826        5.0  173.5   107642
# 20  215.0   20   872.143471  28.948023        5.0  173.5   107642
# 21  225.0   21   772.387324  26.010947        5.0  173.5   107642
# 22  235.0   22   690.316757  26.291322        5.0  173.5   107642
# 23  245.0   23   561.569390  23.199531        5.0  173.5   107642
#
# [69 rows x 7 columns]

# %%
Mll = hdf.get('/Mll')
type(Mll)
print(hdf.get('Mll').shape)
Mll.head(10)
# Out:
# (60, 7)
#       Mll  bin   binContent   binError  binWidth2     mt  scaling
# 1    27.0    1  3360.398470  33.502753        7.0  171.5   111612
# 2    41.0    2  4944.746436  44.534014        7.0  171.5   111612
# 3    55.0    3  6565.289057  48.325362        7.0  171.5   111612
# 4    69.0    4  7561.243113  49.352360        7.0  171.5   111612
# 5    83.0    5  7431.262011  54.730306        7.0  171.5   111612
# 6    97.0    6  6738.239664  54.110558        7.0  171.5   111612
# 7   111.0    7  5873.892897  48.385510        7.0  171.5   111612
# 8   125.0    8  4908.647767  43.719369        7.0  171.5   111612
# 9   139.0    9  4067.714966  39.567336        7.0  171.5   111612
# 10  153.0   10  3340.970169  35.316291        7.0  171.5   111612

# %%
ptll = hdf.get('/ptll')
type(Mll)
print(hdf.get('ptll').shape)
ptll.head(10)
# Out:
# (60, 7)
#     bin    binContent    binError  binWidth2     mt  ptll  scaling
# 1     1   1531.187170   45.820074        5.0  171.5   5.0   111612
# 2     2   4165.661192   81.503647        5.0  171.5  15.0   111612
# 3     3   6294.961445  107.502457        5.0  171.5  25.0   111612
# 4     4   7947.812392  129.449272        5.0  171.5  35.0   111612
# 5     5   9803.652083  147.347595        5.0  171.5  45.0   111612
# 6     6  10925.475456  158.052302        5.0  171.5  55.0   111612
# 7     7  11204.159459  158.697754        5.0  171.5  65.0   111612
# 8     8  10153.912861  143.448318        5.0  171.5  75.0   111612
# 9     9   8908.445714  140.348965        5.0  171.5  85.0   111612
# 10   10   6894.329046  114.478754        5.0  171.5  95.0   111612

# %%
ptneg = hdf.get('/ptneg')
type(ptneg)
print(hdf.get('ptneg').shape)
ptneg.head(10)
# Out:
# (54, 7)
#     bin    binContent    binError  binWidth2     mt  ptneg  scaling
# 1     1  16683.125572  107.188270        5.0  171.5   25.0   111612
# 2     2  17584.984015  127.312906        5.0  171.5   35.0   111612
# 3     3  15097.386920  115.080343        5.0  171.5   45.0   111612
# 4     4  11870.516582  110.513425        5.0  171.5   55.0   111612
# 5     5   9159.885228  108.437275        5.0  171.5   65.0   111612
# 6     6   6929.821662   89.916011        5.0  171.5   75.0   111612
# 7     7   5155.202023   74.970919        5.0  171.5   85.0   111612
# 8     8   3703.475900   66.054638        5.0  171.5   95.0   111612
# 9     9   2790.590191   54.686331        5.0  171.5  105.0   111612
# 10   10   2045.730767   42.851575        5.0  171.5  115.0   111612

# %%
ptp_ptm = hdf.get('/ptp_ptm')
type(ptp_ptm)
print(hdf.get('ptp_ptm').shape)
ptp_ptm.head(10)
# Out:
# (60, 7)
#     bin    binContent    binError  binWidth2     mt  ptp_ptm  scaling
# 1     1   2711.463980   62.954659        5.0  171.5     50.0   111612
# 2     2   6367.408794   93.399857        5.0  171.5     60.0   111612
# 3     3   8965.691509  122.061897        5.0  171.5     70.0   111612
# 4     4   9878.208899  128.835294        5.0  171.5     80.0   111612
# 5     5  10172.853418  136.730281        5.0  171.5     90.0   111612
# 6     6   9702.486966  129.717810        5.0  171.5    100.0   111612
# 7     7   8636.748623  108.325015        5.0  171.5    110.0   111612
# 8     8   7383.189606  111.755421        5.0  171.5    120.0   111612
# 9     9   6095.388028   96.951496        5.0  171.5    130.0   111612
# 10   10   5079.082639   79.052402        5.0  171.5    140.0   111612

# %%
ptpos = hdf.get('/ptpos')
type(ptpos)
print(hdf.get('ptpos').shape)
ptpos.head(10)
# Out:
# (54, 7)
#     bin    binContent    binError  binWidth2     mt  ptpos  scaling
# 1     1  16634.172548  110.782857        5.0  171.5   25.0   111612
# 2     2  17561.768719  125.565955        5.0  171.5   35.0   111612
# 3     3  14973.196248  121.946378        5.0  171.5   45.0   111612
# 4     4  12101.185103  123.731947        5.0  171.5   55.0   111612
# 5     5   9087.560652  109.433189        5.0  171.5   65.0   111612
# 6     6   6886.404594   92.151276        5.0  171.5   75.0   111612
# 7     7   5132.142984   80.026128        5.0  171.5   85.0   111612
# 8     8   3841.406010   67.741955        5.0  171.5   95.0   111612
# 9     9   2829.118654   60.529487        5.0  171.5  105.0   111612
# 10   10   1998.668451   49.161994        5.0  171.5  115.0   111612

# %% [markdown]
# # SciKit Examples
# ### Noiseless Case

# %%
np.random.seed(1)

def f(x):
     return x * np.sin(x)


X = np.atleast_2d([1., 3., 5., 6., 7., 8.]).T
print(X)
# Out:
# [[1.]
#  [3.]
#  [5.]
#  [6.]
#  [7.]
#  [8.]]

# %%
y = f(X).ravel()
print(y)
# Out:
# [ 0.84147098  0.42336002 -4.79462137 -1.67649299  4.59890619  7.91486597]

# %%
x = np.atleast_2d(np.linspace(0, 10, 1000)).T

# %%
kernel = C(1.0, (1e-3, 1e3)) * RBF(10, (1e-2, 1e2))
print(kernel)
# Out:
# 1**2 * RBF(length_scale=10)

# %%
gp = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=9)

# %%
gp.fit(X,y)
# Out:
# GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#                          kernel=1**2 * RBF(length_scale=10),
#                          n_restarts_optimizer=9, normalize_y=False,
#                          optimizer='fmin_l_bfgs_b', random_state=None)

# %%
y_pred, sigma = gp.predict(x, return_std = True)

# %%
plt.figure()
plt.plot(x, f(x), 'r:', label=r'$f(x) = x\,\sin(x)$')
plt.plot(X, y, 'r.', markersize=10, label='Observations')
plt.plot(x, y_pred, 'b-', label='Prediction')
plt.fill(np.concatenate([x, x[::-1]]),
         np.concatenate([y_pred - 1.9600 * sigma,
                        (y_pred + 1.9600 * sigma)[::-1]]),
         alpha=.5, fc='b', ec='None', label='95% confidence interval')
plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.ylim(-10, 20)
plt.legend(loc='upper left')

# %% [markdown]
# ### Noisy Case

# %%
X = np.linspace(0.1, 9.9, 20)
print(X)
# Out:
# [0.1        0.61578947 1.13157895 1.64736842 2.16315789 2.67894737
#  3.19473684 3.71052632 4.22631579 4.74210526 5.25789474 5.77368421
#  6.28947368 6.80526316 7.32105263 7.83684211 8.35263158 8.86842105
#  9.38421053 9.9       ]

# %%
X = np.atleast_2d(X).T
print(X)
# Out:
# [[0.1       ]
#  [0.61578947]
#  [1.13157895]
#  [1.64736842]
#  [2.16315789]
#  [2.67894737]
#  [3.19473684]
#  [3.71052632]
#  [4.22631579]
#  [4.74210526]
#  [5.25789474]
#  [5.77368421]
#  [6.28947368]
#  [6.80526316]
#  [7.32105263]
#  [7.83684211]
#  [8.35263158]
#  [8.86842105]
#  [9.38421053]
#  [9.9       ]]

# %%
y = f(X).ravel()
dy = 0.5 + 1.0 * np.random.random(y.shape)
noise = np.random.normal(0, dy)
y += noise

# %%
gp = GaussianProcessRegressor(kernel=kernel, alpha=dy ** 2,
                              n_restarts_optimizer=10)

gp.fit(X, y)

y_pred, sigma = gp.predict(x, return_std=True)

# %%
plt.figure()
plt.plot(x, f(x), 'r:', label=r'$f(x) = x\,\sin(x)$')
plt.errorbar(X.ravel(), y, dy, fmt='r.', markersize=10, label='Observations')
plt.plot(x, y_pred, 'b-', label='Prediction')
plt.fill(np.concatenate([x, x[::-1]]),
         np.concatenate([y_pred - 1.9600 * sigma,
                        (y_pred + 1.9600 * sigma)[::-1]]),
         alpha=.5, fc='b', ec='None', label='95% confidence interval')
plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.ylim(-10, 20)
plt.legend(loc='upper left')

plt.show()

# %% [markdown]
# # Applying Interpolation
# ### Observable: PtPos

# %%
#Will first start with ptpos

print(hdf.get('ptpos').shape)
ptpos.head(18)
# Out:
# (54, 7)
#     bin    binContent    binError  binWidth2     mt  ptpos  scaling
# 1     1  16634.172548  110.782857        5.0  171.5   25.0   111612
# 2     2  17561.768719  125.565955        5.0  171.5   35.0   111612
# 3     3  14973.196248  121.946378        5.0  171.5   45.0   111612
# 4     4  12101.185103  123.731947        5.0  171.5   55.0   111612
# 5     5   9087.560652  109.433189        5.0  171.5   65.0   111612
# 6     6   6886.404594   92.151276        5.0  171.5   75.0   111612
# 7     7   5132.142984   80.026128        5.0  171.5   85.0   111612
# 8     8   3841.406010   67.741955        5.0  171.5   95.0   111612
# 9     9   2829.118654   60.529487        5.0  171.5  105.0   111612
# 10   10   1998.668451   49.161994        5.0  171.5  115.0   111612
# 11   11   1552.310857   37.886794        5.0  171.5  125.0   111612
# 12   12   1142.700398   29.941035        5.0  171.5  135.0   111612
# 13   13    857.942470   26.958751        5.0  171.5  145.0   111612
# ...

# %%
X = ptpos['bin']
y = ptpos['binContent']
plt.scatter(X, y)
plt.show()
# print(X)

# %%
X = ptpos['bin']
y = ptpos['binError']
plt.scatter(X, y)
plt.show()

# %%
X = ptpos['binContent']
y = ptpos['binError']
plt.scatter(X, y)
plt.show()

# %%
mt = ptpos['mt'].unique()
print(mt)
# Out:
# [171.5 172.5 173.5]

# %%
# Starting with ptpos and mass=171.5

X = []
y = []

binError = ptpos['binError']
data = ptpos['ptpos']
masses = np.array([171.5,172.5,173.5])

X = np.array(data[:18])
y = np.array(binError[:18])

print(type(X))
print(X)
print(type(y))
print(y)

plt.scatter(X, y)
plt.title('PtPos at 171.5 Mass')
plt.xlabel('PtPos')
plt.ylabel('Bin Error')
plt.show()
# Out:
# <class 'numpy.ndarray'>
# [ 25.  35.  45.  55.  65.  75.  85.  95. 105. 115. 125. 135. 145. 155.
#  165. 175. 185. 195.]
# <class 'numpy.ndarray'>
# [110.78285677 125.56595546 121.9463783  123.73194708 109.43318866
#   92.15127587  80.02612767  67.7419547   60.52948681  49.16199435
#   37.88679385  29.94103512  26.95875132  20.4408449   17.20822655
#   13.4823836   11.0013705    9.2246905 ]

# %% [markdown]
# ### SciPy Cubic-spine Interpolation example

# %%
x = np.arange(0, 2*np.pi+np.pi/4, 2*np.pi/8)
y = np.sin(x)
tck = interpolate.splrep(x, y, s=0)
xnew = np.arange(0, 2*np.pi, np.pi/50)
ynew = interpolate.splev(xnew, tck, der=0)

plt.figure()
plt.plot(x, y, 'x', xnew, ynew, xnew, np.sin(xnew), x, y, 'b')
plt.legend(['Linear', 'Cubic Spline', 'True'])
plt.axis([-0.05, 6.33, -1.05, 1.05])
plt.title('Cubic-spline interpolation')
plt.show()

# %% [markdown]
# ### Applying SciKit to PtPos 171.5 mass

# %%
X = []
y = []

events = ptpos['binContent']
data = ptpos['ptpos']

X = np.array(data[:18])
y = np.array(events[:18])

# X = data[:18]
# y = events[:18]

print(np.array(X).shape)
print(np.array(y).shape)

plt.scatter(X, y)
plt.title('PtPos at 171.5 Mass')
plt.xlabel('PtPos')
plt.ylabel('Events')
plt.show()
# Out:
# (18,)
# (18,)

# %%
np.random.seed(1)

data = ptpos['ptpos']
binError = ptpos['binError']
binContent = ptpos['binContent']

X = data[:18].to_numpy()
y = binContent[:18].to_numpy()
dy = binError[:18].to_numpy() # noise

X = np.atleast_2d(X).T

# TODO: Try different kernels
kernel = C(1.0, (1e-3, 1e3)) * RBF(10, (1e-2, 1e2))

# alpha: error at each datapoint
# normalize_y = True  produces better agreement with input template data 
gp = GaussianProcessRegressor(kernel=kernel, alpha=dy,
                              n_restarts_optimizer=10, normalize_y=True)

gp.fit(X, y) 

# Domain to evaluate interpolation at
xmin = ptpos['ptpos'].iloc[0] - ptpos['binWidth2'].iloc[0]
xmax = ptpos['ptpos'].iloc[-1] - ptpos['binWidth2'].iloc[-1]
x = np.atleast_2d(np.linspace(xmin, xmax, 1000)).T

# Do interpolation
y_pred, sigma = gp.predict(x, return_std=True)


plt.figure()

# Known points
plt.errorbar(X.ravel(), y, dy, fmt='r.', markersize=10, label='Observations')

# Interpolated points
plt.plot(x, y_pred, 'b-', label='Prediction')
plt.fill(np.concatenate([x, x[::-1]]), \
         np.concatenate([y_pred - 1.9600 * sigma,\
                        (y_pred + 1.9600 * sigma)[::-1]]),\
         alpha=.5, fc='b', ec='None', label='95% confidence interval')

plt.legend(loc='upper right')
plt.title('ptpos NNLO m = 171.5')
plt.xlabel('ptpos [GeV]')
plt.ylabel("Events")

plt.show()

# %% [markdown]
# ### Resources
#
# SciPy
# - https://programandociencia.com/2015/10/29/interpolating-functions-on-your-data-using-python-part-1/
# - https://mmas.github.io/interpolation-scipy
# - https://docs.scipy.org/doc/scipy/reference/tutorial/interpolate.html#d-interpolation-interp1d
#
# SciKit
# - https://scikit-learn.org/stable/modules/generated/sklearn.gaussian_process.kernels.RBF.html
#
# GPy
# - https://nbviewer.ipython.org/github/SheffieldML/notebook/blob/master/GPy/index.ipynb
#
# misc
# - https://www.cs.toronto.edu/~duvenaud/cookbook/
# - https://datascience.stackexchange.com/questions/31947/how-do-i-interpret-the-length-scale-parameter-of-the-rbf-kernel
# - https://en.wikipedia.org/wiki/Gaussian_process

# %% [markdown]
# ### To Do
# - Calculate the 1 sigma confidence interval (67%) instead of the 2 sigma (95%).
# - Try different kernel functions
# - Extend example to 2D (?) and 3D --> 3D histogram
